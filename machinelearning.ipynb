# %%
# !pip3 install indic-nlp-library
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch
from indicnlp.tokenize import indic_tokenize
import torch.nn.functional as F

print("All imports successful")
# Out:
# All imports successful

# %%
data = pd.read_csv("/kaggle/input/language-dataset/Sentence pairs in English-Hindi - 2025-02-11.tsv",
                  sep="\t",header=None,names=["SrcSentID","SrcSent","DstSentID","DstSent"])

# %%
data.head()
# Out:
#    SrcSentID                                  SrcSent  DstSentID  \
# 0       1282                       Muiriel is 20 now.     485968
# 1       1282                       Muiriel is 20 now.    2060319
# 2       1294  Education in this world disappoints me.     485564
# 3       1302                       That won't happen.    2060320
# 4       1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer = AutoTokenizer.from_pretrained("google-T5/T5-base")

# %%
data["SrcSent"] = data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data["SrcSent"] = data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)

# %%
Vs = src_sent_tokenizer.get_vocab()

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
hindi_vocab = set()

for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)

# %%
Vd = dict()
for idx, token in enumerate(hindi_vocab):
    Vd[token] = idx + 3
Vd["<PAD>"] = 0
Vd["<SOS>"] = 1
Vd["<EOS>"] = 2

# %%
hindi_idx2vocab = dict(zip(Vd.values(), Vd.keys()))
print(hindi_idx2vocab)
# Out:
# {3: 'वयस्क', 4: 'डरी', 5: 'राज्य', 6: 'भरा', 7: 'प्रयोग', 8: 'टिकटें', 9: 'रबड़', 10: 'तम्बू', 11: 'एतराज़', 12: 'बदकिस्मती', 13: 'पुराणों', 14: 'नेहा', 15: 'जिसका', 16: 'लाइका', 17: 'खुले', 18: 'अधिकांश', 19: 'रच', 20: 'रॉबर्ट', 21: 'शाकारी', 22: 'जुर्म', 23: 'स्पैनिश', 24: 'गाऊँगी', 25: 'तरफ', 26: 'प्रोफेसर', 27: 'सूज', 28: 'मिटाइए', 29: 'गिर', 30: 'उड़ने', 31: 'मनोचिकित्सा', 32: '€100', 33: 'नागरिक', 34: 'सेंटर', 35: 'पड़ेगी', 36: 'शुरू', 37: 'लिखीं', 38: 'सभ्यताओं', 39: 'टूट', 40: 'चुपचाप', 41: 'झटके', 42: 'आत्मा', 43: 'ग़ुस्से', 44: 'पुआ', 45: 'लाइए', 46: 'नये', 47: 'वरदान', 48: 'दौलत', 49: 'नौसैनिक', 50: 'इंक़िलाब', 51: 'रेपुबलिका', 52: 'पसंद', 53: 'मूँछ', 54: 'फिराया', 55: 'मरोगे', 56: 'धुलने', 57: 'आगे', 58: 'Tatoeba', 59: 'सीढ़ियाँ', 60: 'हिस्सो', 61: 'कमा', 62: 'चंद', 63: 'बजाने', 64: 'फेंक', 65: 'आख़िरकार', 66: 'झेल', 67: 'छूट', 68: 'मिठाईयाँ', 69: 'झूठी', 70: 'गिलहरी', 71: 'मनमोहक', 72: 'सूखा', 73: 'तोह्फ़ा', 74: 'तारीफ़', 75: 'सुपर', 76: 'परिस्तिथि', 77: 'ग्रामवासी', 78: 'दफ़न', 79: 'लिया', 80: 'रटना', 81: 'ऑस्ट्रेल्या', 82: 'यरुशलम', 83: 'डुबो', 84: 'बजे', 85: 'आइडिया', 86: 'चाहूंगा', 87: 'सम्बंध', 88: 'शैतान', 89: 'अँगूठी', 90: 'सामी', 91: 'कानूनों', 92: 'नगरी', 93: 'वादा', 94: 'दफ्तर', 95: 'सायकल', 96: 'टैक्सी', 97: 'दर्द', 98: 'निम्नलिखित', 99: 'महसूस', 100: 'रसोई', 101: 'बर्ट', 102: 'बौद्ध', 103: 'बाली', 104: 'बोते', 105: 'नाराज़', 106: 'निकालते', 107: 'जचती', 108: 'बढ़ाने', 109: 'प्राकृतिक', 110: 'आईं', 111: 'ड्राईव', 112: 'दिखाइए', 113: 'ऊर्जा', 114: 'रिरियाने', 115: 'मामूली', 116: 'राजेंद्र', 117: 'देखो', 118: 'बंदोबस्त', 119: 'तोता', 120: 'आँगन', 121: 'सही', 122: 'जीत', 123: 'पागल', 124: 'डोनट', 125: 'कुत्ते', 126: 'नशा', 127: 'अनन्त', 128: 'मील', 129: 'सत्य', 130: 'सिखाते', 131: 'ही', 132: 'पेन्सिलें', 133: 'ख़ालिद', 134: 'हाय', 135: 'चुनौतीपूर्ण', 136: 'दूँ', 137: 'बहनें', 138: 'पेड़ों', 139: 'वाइन', 140: 'पढ़ें', 141: 'करूं', 142: 'विपत्ती', 143: 'बीटल', 144: 'हमारा', 145: 'मन', 146: 'लिहाज़', 147: 'गणित', 148: 'अॅन', 149: 'घंटों', 150: 'स्वीडिश', 151: 'स्क्रू', 152: 'सौंदरराजन', 153: 'दिवाली', 154: 'घूरकर', 155: 'जानती', 156: 'कैसा', 157: 'आकर्षक', 158: 'इशारा', 159: 'इसकी', 160: 'यीशु', 161: 'फ़्रिज', 162: 'बताया', 163: 'पाय', 164: 'पर्स', 165: 'प्लैन', 166: 'लेटा', 167: 'कविताएँ', 168: 'उठिए', 169: 'आठ', 170: 'सिक्कों', 171: 'चिल्ला', 172: 'इमारतें', 173: 'बोला', 174: 'तस्वीर', 175: 'विस्मृत', 176: 'ज़रा', 177: 'दिखें', 178: 'टाम', 179: 'यात्रियों', 180: 'कविताएं', 181: 'सॅटाइरिकॉन', 182: 'हाफ़िज़', 183: 'दौड़ते', 184: 'गिरती', 185: 'मिन्ह', 186: 'पैगंबर', 187: 'स्थान', 188: 'चहरा', 189: 'मेइन', 190: 'युरों', 191: 'कागज़ी', 192: 'कोयल', 193: 'भेंट', 194: 'सहमत', 195: 'बेनाम', 196: 'बधाई', 197: 'गवाह', 198: 'व्यक्तिगत', 199: 'वर्ष', 200: 'खेलतें', 201: 'निकालें', 202: 'मिलेंगे', 203: 'बॉस', 204: 'चाहो', 205: 'बेसुखद', 206: 'चलाना', 207: 'सनकी', 208: 'दुर्प्रभावों', 209: 'हस्तमैतुन', 210: 'अगले', 211: 'सर्वोच्च', 212: 'युगांडा', 213: 'गुजरात', 214: 'हारोगे', 215: 'पैर', 216: 'कर्णाटक', 217: 'लो', 218: 'आदमियों', 219: 'रॉक', 220: 'खोलें', 221: 'लौटूँगी', 222: 'निवासियों', 223: 'फ़ॉस्टर', 224: 'कैसे', 225: 'माननी', 226: 'कि', 227: 'सोकर', 228: 'दूसरो', 229: 'बनाए', 230: 'टोनी', 231: 'अध्यापक', 232: 'रिकॉर्ड', 233: 'मामलकह', 234: 'बोलिए', 235: 'ब्यौरा', 236: 'तरक़ीब', 237: 'अहसास', 238: 'भेजने', 239: 'पार्थिव', 240: 'बिछाई', 241: 'परिवर्तित', 242: 'मार्क्स', 243: 'लगाना', 244: 'भूखा', 245: 'मारिया', 246: 'घृणा', 247: 'हमने', 248: 'टाफ़्ट', 249: 'फिसलती', 250: 'विद्वान', 251: 'गौरव', 252: 'हटाने', 253: 'रोल', 254: 'ज़रूर', 255: 'बिल्कुल', 256: 'मनचाही', 257: 'नीगाता', 258: 'नक़्शे', 259: 'डोमिनिकन', 260: 'प्रवीण', 261: 'पाता', 262: 'होके', 263: 'धूम्रपान', 264: 'जाचुका', 265: 'चौहत्तर', 266: 'बाद', 267: 'बारी', 268: 'पत्र', 269: 'पुनर्विवाह', 270: 'तीसरी', 271: 'घर', 272: '८', 273: 'लौटूँगा', 274: 'लज़ीज़', 275: 'देती', 276: 'संभालने', 277: 'मंज़िलें', 278: 'बॉयफ्रेंड', 279: 'फ़ाहिमा', 280: 'झगड़', 281: 'जानों', 282: 'बचाई', 283: 'मुग़ल', 284: 'क्षमता', 285: 'ग्रामीण', 286: 'सूप', 287: 'गाओ', 288: 'मोरोपं ...

# %%
def convert_hindi_tokens_to_ids(hindi_sent):
    return [Vd[token] for token in hindi_sent]

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: convert_hindi_tokens_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [1596, 2130, 4593, 6123, 2582, 4761, 4937, 663...
# 1         [1596, 2130, 4593, 6123, 2582, 6630, 6342]
# 2  [1638, 6378, 4596, 3798, 6512, 6808, 1913, 313...
# 3                            [3761, 570, 6552, 6342]
# 4          [2705, 5685, 1184, 753, 1820, 6630, 6342]

# %%
def insert_sos_token_id(hindi_sent_token_ids):
    return [1] + hindi_sent_token_ids

# %%
data["DstSentInput"] = data["DstSent"].apply(lambda x: insert_sos_token_id(x))

# %%
def insert_eos_token_id(hindi_sent_token_ids):
    return hindi_sent_token_ids + [2]

# %%
data["DstSentLabel"] = data["DstSent"].apply(lambda x: insert_eos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [1596, 2130, 4593, 6123, 2582, 4761, 4937, 663...
# 1         [1596, 2130, 4593, 6123, 2582, 6630, 6342]
# 2  [1638, 6378, 4596, 3798, 6512, 6808, 1913, 313...
# 3                            [3761, 570, 6552, 6342]
# 4          [2705, 5685, 1184, 753, 1820, 6630, 6342]
#
#                                         DstSentInput  \
# 0  [1, 1596, 2130, 4593, 6123, 2582, 4761, 4937, ...
# 1      [1, 1596, 2130, 4593, 6123, 2582, 6630, 6342]
# 2  [1, 1638, 6378, 4596, 3798, 6512, 6808, 1913, ...
# 3                         [1, 3761, 570, 6552, 6342]
# 4       [1, 2705, 5685, 1184, 753, 1820, 6630, 6342]
#
#                                         DstSentLabel
# 0  [1596, 2130, 4593, 6123, 2582, 4761, 4937, 663...
# 1      [1596, 2130, 4593, 6123, 2582, 6630, 6342, 2]
# 2  [1638, 6378, 4596, 3798, 6512, 6808, 1913, 313...
# 3                         [3761, 570, 6552, 6342, 2]
# 4       [2705, 5685, 1184, 753, 1820, 6630, 6342, 2]

# %%
data.drop(labels=[data.columns[1]],axis=1,inplace=True)

# %%
X = list(data["SrcSent"])
Y_input = list(data["DstSentInput"])
Y_label = list(data["DstSentLabel"])

# %%
X_tensor = [torch.tensor(tokenized_eng_sent_ids) for tokenized_eng_sent_ids in X]
Y_input_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_input]
Y_label_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_label]

# %%
X_padded = torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first=True)
Y_padded_input = torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first=True)
Y_padded_label = torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first=True)

# %%
Ns = X_padded.shape[1]
Nd = Y_padded_label.shape[1]

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=src_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)

    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out = self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)

        return encoder_output, (final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):

    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()

        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=dst_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)
        self.prediction_layer = torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        #self.prediction_layer_activation = torch.nn.Softmax(dim=2)

    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):

        first_embedding_layer_out = self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out, final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                         (final_encoder_output,
                                                                                                          final_cell_state))
        prediction = self.prediction_layer(decoder_lstm_layer_out)
        
        return prediction, (final_decoder_lstm_layer_out, final_cell_state)

# %%
class Seq2SeqEncDec(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,dst_lang_vocab_size,word_embedding_dim):
        super(Seq2SeqEncDec,self).__init__()

        self.encoder = Encoder(src_lang_vocab_size,word_embedding_dim)
        self.decoder = Decoder(dst_lang_vocab_size,word_embedding_dim)

    def forward(self,X_padded_mini_batch,Y_padded_input_mini_batch):

        encoder_output, (final_encoder_output,final_cell_state) = self.encoder(X_padded_mini_batch)
        y_hat_mini_batch = self.decoder(Y_padded_input_mini_batch,
                                        final_encoder_output,final_cell_state)

        return y_hat_mini_batch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cuda

# %%
X_padded_train = X_padded[0:13000]
Y_padded_input_train = Y_padded_input[0:13000]
Y_padded_label_train = Y_padded_label[0:13000]

X_padded_test = X_padded[13000:]
Y_padded_input_test = Y_padded_input[13000:]
Y_padded_label_test = Y_padded_label[13000:]

# %%
network = Seq2SeqEncDec(len(Vs),len(Vd),128).to(device)

# %%
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(network.parameters())
num_epochs = 250
mb_size = 65

for epoch in range(num_epochs):
    for i in range(X_padded_train.shape[0]//mb_size):

        X_train_mb = X_padded_train[i*mb_size:(i+1)*mb_size]
        Y_input_mb = Y_padded_input_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_padded_label_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_label_mb.reshape(Y_label_mb.shape[0]*Y_label_mb.shape[1],)
        
        X_train_mb, Y_input_mb, Y_label_mb = X_train_mb.to(device), Y_input_mb.to(device), Y_label_mb.to(device)

        y_hat_train_mb = network(X_train_mb,Y_input_mb)
        y_hat_train_mb = y_hat_train_mb[0]
        y_hat_train_mb = y_hat_train_mb.reshape(y_hat_train_mb.shape[0]*y_hat_train_mb.shape[1],
                                                y_hat_train_mb.shape[2])

        loss_fn_value = loss_fn(y_hat_train_mb,Y_label_mb)

        loss_fn_value.backward()
        #torch.nn.utils.clip_grad_norm_(network.parameters(),max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        print("Epoch # {}, Time Step # {}, Loss Value = {}".format(epoch,i,loss_fn_value))
# Out:
# Epoch # 0, Time Step # 0, Loss Value = 8.888349533081055
# Epoch # 0, Time Step # 1, Loss Value = 8.840303421020508
# Epoch # 0, Time Step # 2, Loss Value = 8.807218551635742
# Epoch # 0, Time Step # 3, Loss Value = 8.795755386352539
# Epoch # 0, Time Step # 4, Loss Value = 8.775224685668945
# Epoch # 0, Time Step # 5, Loss Value = 8.724142074584961
# Epoch # 0, Time Step # 6, Loss Value = 8.725821495056152
# Epoch # 0, Time Step # 7, Loss Value = 8.6615629196167
# Epoch # 0, Time Step # 8, Loss Value = 8.643916130065918
# Epoch # 0, Time Step # 9, Loss Value = 8.598362922668457
# Epoch # 0, Time Step # 10, Loss Value = 8.512667655944824
# Epoch # 0, Time Step # 11, Loss Value = 8.464422225952148
# Epoch # 0, Time Step # 12, Loss Value = 8.321881294250488
# Epoch # 0, Time Step # 13, Loss Value = 8.346323013305664
# Epoch # 0, Time Step # 14, Loss Value = 8.181441307067871
# Epoch # 0, Time Step # 15, Loss Value = 8.101869583129883
# Epoch # 0, Time Step # 16, Loss Value = 7.936958312988281
# Epoch # 0, Time Step # 17, Loss Value = 7.767715930938721
# Epoch # 0, Time Step # 18, Loss Value = 7.528624057769775
# Epoch # 0, Time Step # 19, Loss Value = 7.541256427764893
# Epoch # 0, Time Step # 20, Loss Value = 7.327613830566406
# Epoch # 0, Time Step # 21, Loss Value = 7.179862976074219
# Epoch # 0, Time Step # 22, Loss Value = 6.883749961853027
# Epoch # 0, Time Step # 23, Loss Value = 6.7933220863342285
# Epoch # 0, Time Step # 24, Loss Value = 6.863799095153809
# Epoch # 0, Time Step # 25, Loss Value = 6.715338230133057
# Epoch # 0, Time Step # 26, Loss Value = 6.46519136428833
# Epoch # 0, Time Step # 27, Loss Value = 6.427846908569336
# Epoch # 0, Time Step # 28, Loss Value = 6.23595666885376
# Epoch # 0, Time Step # 29, Loss Value = 6.125218391418457
# Epoch # 0, Time Step # 30, Loss Value = 5.953898906707764
# Epoch # 0, Time Step # 31, Loss Value = 5.877340316772461
# Epoch # 0, Time Step # 32, Loss Value = 5.7175068855285645
# Epoch # 0, Time Step # 33, Loss Value = 5.71960973739624
# Epoch # 0, Time Step # 34, Loss Value = 5.950405120849609
# Epoch # 0, Time Step # 35, Loss Value = 6.157534599304199
# Epoch # 0, Time Step # 36, Loss Value = 6.173865795135498
# Epoch # 0, Time Step # 37, Loss Value = 5.9593939781188965
# Epoch # 0, Time Step # 38, Loss Value = 6.001644611358643
# Epoch # 0, Time Step # 39, Loss Value = 5.969768047332764
# Epoch # 0, Time Step # 40, Loss Value = 5.687407970428467
# Epoch # 0, Time Step # 41, Loss Value = 5.875416278839111
# Epoch # 0, Time Step # 42, Loss Value = 5.504974365234375
# Epoch # 0, Time Step # 43, Loss Value = 5.7899627685546875
# Epoch # 0, Time Step # 44, Loss Value = 5.55466365814209
# Epoch # 0, Time Step # 45, Loss Value = 5.564083099365234
# Epoch # 0, Time Step # 46, Loss Value = 5.789834022521973
# Epoch # 0, Time Step # 47, Loss Value = 5.4482293128967285
# Epoch # 0, Time Step # 48, Loss Value = 5.602789402008057
# Epoch # 0, Time Step # 49, Loss Value = 5.449893951416016
# Epoch # 0, Time Step # 50, Loss Value = 5.4960126876831055
# Epoch # 0, Time Step # 51, Loss Value = 5.635904788970947
# Epoch # 0, Time Step # 52, Loss Value = 5.752290725708008
# Epoch # 0, Time Step # 53, Loss Value = 5.625665187835693
# Epoch # 0, Time Step # 54, Loss Value = 5.804739952087402
# Epoch # 0, Time Step # 55, Loss Value = 6.012475967407227
# Epoch # 0, Time Step # 56, Loss Value = 5.4609575271606445
# Epoch # 0, Time Step # 57, Loss Value = 5.68046236038208
# Epoch # 0, Time Step # 58, Loss Value = 5.670527935028076
# Epoch # 0, Time Step # 59, Loss Value = 5.137203216552734
# Epoch # 0, Time Step # 60, Loss Value = 5.224756717681885
# Epoch # 0, Time Step # 61, Loss Value = 5.2922868728637695
# Epoch # 0, Time Step # 62, Loss Value = 5.818968296051025
# Epoch # 0, Time Step # 63, Loss Value = 5.995077133178711
# Epoch # 0, Time Step # 64, Loss Value = 5.4680657386779785
# Epoch # 0, Time Step # 65, Loss Value = 5.676637649536133
# Epoch # 0, Time Step # 66, Loss Value = 6.089611530303955
# Epoch # 0, Time Step # 67, Loss Value = 6.227619171142578
# Epoch # 0, Time Step # 68, Loss Value = 5.656003475189209
# Epoch # 0, Time Step # 69, Loss Value = 6.2180867195129395
# Epoch # 0, Time Step # 70, Loss Value = 5.678333282470703
# Epoch # 0, Time Step # 71, Loss Value = 5.7642998695373535
# Epoch # 0, Time Step # 72, Loss Value = 5.570816993713379
# Epoch # 0, Time Step # 73, Loss Value = 5.95597505569458
# Epoch # 0, Time Step # 74, Loss Value = 5.671268939971924
# Epoch # 0, Time Step # 75, Loss Value = 5.655434608459473
# Epoch # 0, Time Step # 76, Loss Value = 5.767570972442627
# Epoch # 0, Time Step # 77, Loss Value = 5.617762565612793
# Epoch # 0, Time Step # 78, Loss Value = 5.310532093048096
# Epoch # 0, Time Step # 79, Loss Value = 5.72193717956543
# Epoch # 0, Time Step # 80, Loss Value = 4.954626560211182
# Epoch # 0, Time Step # 81, Loss Value = 5.386829853057861
# Epoch # 0, Time Step # 82, Loss Value = 4.973294734954834
# Epoch # 0, Time Step # 83, Loss Value = 5.224855899810791
# Epoch # 0, Time Step # 84, Loss Value = 5.0996174812316895
# Epoch # 0, Time Step # 85, Loss Value = 4.894989490509033
# Epoch # 0, Time Step # 86, Loss Value = 4.709148406982422
# Epoch # 0, Time Step # 87, Loss Value = 4.752236366271973
# Epoch # 0, Time Step # 88, Loss Value = 4.962623596191406
# Epoch # 0, Time Step # 89, Loss Value = 4.881744384765625
# Epoch # 0, Time Step # 90, Loss Value = 4.28347635269165
# Epoch # 0, Time Step # 91, Loss Value = 4.594320774078369
# Epoch # 0, Time Step # 92, Loss Value = 5.4873785972595215
# Epoch # 0, Time Step # 93, Loss Value = 4.4236159324646
# Epoch # 0, Time Step # 94, Loss Value = 5.460367202758789
# Epoch # 0, Time Step # 95, Loss Value = 6.600759506225586
# Epoch # 0, Time Step # 96, Loss Value = 6.6660847663879395
# Epoch # 0, Time Step # 97, Loss Value = 5.453835487365723
# Epoch # 0, Time Step # 98, Loss Value = 4.837989807128906
# Epoch # 0, Time Step # 99, Loss Value = 5.008481025695801
# Epoch # 0, Time Step # 100, Loss Value = 5.135348320007324
# Epoch # 0, Time Step # 101, Loss Value = 4.420254230499268
# Epoch # 0, Time Step # 102, Loss Value = 4.276996612548828
# Epoch # 0, Time Step # 103, Loss Value = 4.779427528381348
# Epoch # 0, Time Step # 104, Loss Value = 4.810671329498291
# Epoch # 0, Time Step # 105, Loss Value = 4.6801605224609375
# Epoch # 0, Time Step # 106, Loss Value = 4.667620658874512
# Epoch # 0, Time Step # 107, Loss Value = 4.294399738311768
# Epoch # 0, Time Step # 108, Loss Value = 4.590930461883545
# Epoch # 0, Time Step # 109, Loss Value = 4.282922744750977
# Epoch # 0, Time Step # 110, Loss Value = 4.520263671875
# Epoch # 0, Time Step # 111, Loss Value = 5.628088474273682
# Epoch # 0, Time Step # 112, Loss Value = 6.120660781860352
# Epoch # 0, Time Step # 113, Loss Value = 5.529022216796875
# Epoch # 0, Time Step # 114, Loss Value = 5.0413007736206055
# Epoch # 0, Time Step # 115, Loss Value = 5.000204086303711
# Epoch # 0, Time Step # 116, Loss Value = 5.2272186279296875
# Epoch # 0, Time Step # 117, Loss Value = 5.02275276184082
# Epoch # 0, Time Step # 118, Loss Value = 4.7274065017700195
# Epoch # 0, Time Step # 119, Loss Value = 5.244070529937744
# Epoch # 0, Time Step # 120, Loss Value = 5.550475597381592
# Epoch # 0, Time Step # 121, Loss Value = 4.567116737365723
# Epoch # 0, Time Step # 122, Loss Value = 4.851906776428223
# Epoch # 0, Time Step # 123, Loss Value = 4.768843173980713
# Epoch # 0, Time Step # 124, Loss Value = 4.63282585144043
# Epoch # 0, Time Step # 125, Loss Value = 4.781941890716553
# Epoch # 0, Time Step # 126, Loss Value = 4.738710403442383
# Epoch # 0, Time Step # 127, Loss Value = 4.846543312072754
# Epoch # 0, Time Step # 128, Loss Value = 5.383266448974609
# Epoch # 0, Time Step # 129, Loss Value = 5.546195983886719
# Epoch # 0, Time Step # 130, Loss Value = 5.471733093261719
# Epoch # 0, Time Step # 131, Loss Value = 4.906414031982422
# Epoch # 0, Time Step # 132, Loss Value = 4.549991607666016
# Epoch # 0, Time Step # 133, Loss Value = 4.311114311218262
# Epoch # 0, Time Step # 134, Loss Value = 4.8512043952941895
# Epoch # 0, Time Step # 135, Loss Value = 4.57188606262207
# Epoch # 0, Time Step # 136, Loss Value = 4.75733757019043
# Epoch # 0, Time Step # 137, Loss Value = 5.0015692710876465
# Epoch # 0, Time Step # 138, Loss Value = 4.4926066398620605
# Epoch # 0, Time Step # 139, Loss Value = 5.1611857414245605
# Epoch # 0, Time Step # 140, Loss Value = 4.849818229675293
# Epoch # 0, Time Step # 141, Loss Value = 4.602286338806152
# Epoch # 0, Time Step # 142, Loss Value = 4.441856384277344
# Epoch # 0, Time Step # 143, Loss Value = 4.720728397369385
# Epoch # 0, Time Step # 144, Loss Value = 4.390873908996582
# Epoch # 0, Time Step # 145, Loss Value = 4.377137184143066
# Epoch # 0, Time Step # 146, Loss Value = 4.317575454711914
# Epoch # 0, Time Step # 147, Loss Value = 4.999386787414551
# Epoch # 0, Time Step # 148, Loss Value = 4.618441104888916
# Epoch # 0, Time Step # 149, Loss Value = 4.828470230102539
# Epoch # 0, Time Step # 150, Loss Value = 4.599630355834961
# Epoch # 0, Time Step # 151, Loss Value = 4.740599632263184
# Epoch # 0, Time Step # 152, Loss Value = 4.8793864250183105
# Epoch # 0, Time Step # 153, Loss Value = 4.565130710601807
# Epoch # 0, Time Step # 154, Loss Value = 4.47287654876709
# Epoch # 0, Time Step # 155, Loss Value = 4.705373287200928
# Epoch # 0, Time Step # 156, Loss Value = 4.760201930999756
# Epoch # 0, Time Step # 157, Loss Value = 4.649184703826904
# Epoch # 0, Time Step # 158, Loss Value = 4.635033130645752
# Epoch # 0, Time Step # 159, Loss Value = 5.613353252410889
# Epoch # 0, Time Step # 160, Loss Value = 5.364988803863525
# Epoch # 0, Time Step # 161, Loss Value = 5.653066635131836
# Epoch # 0, Time Step # 162, Loss Value = 5.528530120849609
# Epoch # 0, Time Step # 163, Loss Value = 5.1183929443359375
# Epoch # 0, Time Step # 164, Loss Value = 5.112377166748047
# Epoch # 0, Time Step # 165, Loss Value = 4.915393352508545
# Epoch # 0, Time Step # 166, Loss Value = 4.815856456756592
# Epoch # 0, Time Step # 167, Loss Value = 5.31221342086792
# Epoch # 0, Time Step # 168, Loss Value = 4.940629005432129
# Epoch # 0, Time Step # 169, Loss Value = 5.087095260620117
# Epoch # 0, Time Step # 170, Loss Value = 5.17241096496582
# Epoch # 0, Time Step # 171, Loss Value = 5.2284770011901855
# Epoch # 0, Time Step # 172, Loss Value = 5.578366756439209
# Epoch # 0, Time Step # 173, Loss Value = 5.249403953552246
# Epoch # 0, Time Step # 174, Loss Value = 5.413620471954346
# Epoch # 0, Time Step # 175, Loss Value = 4.896405220031738
# Epoch # 0, Time Step # 176, Loss Value = 4.73164176940918
# Epoch # 0, Time Step # 177, Loss Value = 4.7803192138671875
# Epoch # 0, Time Step # 178, Loss Value = 5.0915422439575195
# Epoch # 0, Time Step # 179, Loss Value = 4.929183006286621
# Epoch # 0, Time Step # 180, Loss Value = 5.230745792388916
# Epoch # 0, Time Step # 181, Loss Value = 4.91513204574585
# Epoch # 0, Time Step # 182, Loss Value = 4.656510353088379
# Epoch # 0, Time Step # 183, Loss Value = 4.725496292114258
# Epoch # 0, Time Step # 184, Loss Value = 4.7843756675720215
# Epoch # 0, Time Step # 185, Loss Value = 4.741295337677002
# Epoch # 0, Time Step # 186, Loss Value = 4.8514580726623535
# Epoch # 0, Time Step # 187, Loss Value = 5.851500511169434
# Epoch # 0, Time Step # 188, Loss Value = 4.73298454284668
# Epoch # 0, Time Step # 189, Loss Value = 4.778600692749023
# Epoch # 0, Time Step # 190, Loss Value = 4.744146823883057
# Epoch # 0, Time Step # 191, Loss Value = 4.7469611167907715
# Epoch # 0, Time Step # 192, Loss Value = 4.912510871887207
# Epoch # 0, Time Step # 193, Loss Value = 4.517457008361816
# Epoch # 0, Time Step # 194, Loss Value = 4.805479526519775
# Epoch # 0, Time Step # 195, Loss Value = 5.013678550720215
# Epoch # 0, Time Step # 196, Loss Value = 5.223578453063965
# Epoch # 0, Time Step # 197, Loss Value = 4.934528827667236
# Epoch # 0, Time Step # 198, Loss Value = 4.865208148956299
# Epoch # 0, Time Step # 199, Loss Value = 4.919259548187256
# Epoch # 1, Time Step # 0, Loss Value = 4.73965311050415
# Epoch # 1, Time Step # 1, Loss Value = 5.132043838500977
# Epoch # 1, Time Step # 2, Loss Value = 5.08579683303833
# Epoch # 1, Time Step # 3, Loss Value = 5.506030559539795
# Epoch # 1, Time Step # 4, Loss Value = 5.545622825622559
# Epoch # 1, Time Step # 5, Loss Value = 5.2437286376953125
# Epoch # 1, Time Step # 6, Loss Value = 5.443893909454346
# Epoch # 1, Time Step # 7, Loss Value = 5.373264789581299
# Epoch # 1, Time Step # 8, Loss Value = 5.4792351722717285
# Epoch # 1, Time Step # 9, Loss Value = 5.500632286071777
# Epoch # 1, Time Step # 10, Loss Value = 5.115254878997803
# Epoch # 1, Time Step # 11, Loss Value = 5.421233654022217
# Epoch # 1, Time Step # 12, Loss Value = 5.041757583618164
# Epoch # 1, Time Step # 13, Loss Value = 5.518128395080566
# Epoch # 1, Time Step # 14, Loss Value = 5.3925275802612305
# Epoch # 1, Time Step # 15, Loss Value = 5.39300012588501
# Epoch # 1, Time Step # 16, Loss Value = 5.130534648895264
# Epoch # 1, Time Step # 17, Loss Value = 5.300761699676514
# Epoch # 1, Time Step # 18, Loss Value = 5.092864036560059
# Epoch # 1, Time Step # 19, Loss Value = 5.347945690155029
# Epoch # 1, Time Step # 20, Loss Value = 5.243525505065918
# Epoch # 1, Time Step # 21, Loss Value = 5.057286262512207
# Epoch # 1, Time Step # 22, Loss Value = 4.843820571899414
# Epoch # 1, Time Step # 23, Loss Value = 5.1707634925842285
# Epoch # 1, Time Step # 24, Loss Value = 5.482150077819824
# Epoch # 1, Time Step # 25, Loss Value = 5.233820915222168
# Epoch # 1, Time Step # 26, Loss Value = 5.1448187828063965
# Epoch # 1, Time Step # 27, Loss Value = 5.281805038452148
# Epoch # 1, Time Step # 28, Loss Value = 5.027235507965088
# Epoch # 1, Time Step # 29, Loss Value = 5.053731918334961
# Epoch # 1, Time Step # 30, Loss Value = 4.939112663269043
# Epoch # 1, Time Step # 31, Loss Value = 4.915600299835205
# Epoch # 1, Time Step # 32, Loss Value = 4.848283290863037
# Epoch # 1, Time Step # 33, Loss Value = 4.929926872253418
# Epoch # 1, Time Step # 34, Loss Value = 5.187948703765869
# Epoch # 1, Time Step # 35, Loss Value = 5.424445152282715
# Epoch # 1, Time Step # 36, Loss Value = 5.471103191375732
# Epoch # 1, Time Step # 37, Loss Value = 5.380022048950195
# Epoch # 1, Time Step # 38, Loss Value = 5.2892937660217285
# Epoch # 1, Time Step # 39, Loss Value = 5.361110210418701
# Epoch # 1, Time Step # 40, Loss Value = 5.122883319854736
# Epoch # 1, Time Step # 41, Loss Value = 5.2070207595825195
# Epoch # 1, Time Step # 42, Loss Value = 4.87465238571167
# Epoch # 1, Time Step # 43, Loss Value = 5.134061813354492
# Epoch # 1, Time Step # 44, Loss Value = 4.9046502113342285
# Epoch # 1, Time Step # 45, Loss Value = 4.945742130279541
# Epoch # 1, Time Step # 46, Loss Value = 5.222618579864502
# Epoch # 1, Time Step # 47, Loss Value = 4.85205078125
# Epoch # 1, Time Step # 48, Loss Value = 5.064949035644531
# Epoch # 1, Time Step # 49, Loss Value = 4.9386773109436035
# Epoch # 1, Time Step # 50, Loss Value = 4.885946273803711
# Epoch # 1, Time Step # 51, Loss Value = 5.063185691833496
# Epoch # 1, Time Step # 52, Loss Value = 5.259007453918457
# Epoch # 1, Time Step # 53, Loss Value = 5.0672173500061035
# Epoch # 1, Time Step # 54, Loss Value = 5.307419300079346
# Epoch # 1, Time Step # 55, Loss Value = 5.2899370193481445
# Epoch # 1, Time Step # 56, Loss Value = 4.865312099456787
# Epoch # 1, Time Step # 57, Loss Value = 5.065733909606934
# Epoch # 1, Time Step # 58, Loss Value = 5.062632083892822
# Epoch # 1, Time Step # 59, Loss Value = 4.547314643859863
# Epoch # 1, Time Step # 60, Loss Value = 4.60757303237915
# Epoch # 1, Time Step # 61, Loss Value = 4.734251022338867
# Epoch # 1, Time Step # 62, Loss Value = 5.250267028808594
# Epoch # 1, Time Step # 63, Loss Value = 5.408226490020752
# Epoch # 1, Time Step # 64, Loss Value = 4.86294412612915
# Epoch # 1, Time Step # 65, Loss Value = 5.1459760665893555
# Epoch # 1, Time Step # 66, Loss Value = 5.353981971740723
# Epoch # 1, Time Step # 67, Loss Value = 5.585995197296143
# Epoch # 1, Time Step # 68, Loss Value = 5.071008205413818
# Epoch # 1, Time Step # 69, Loss Value = 5.642646312713623
# Epoch # 1, Time Step # 70, Loss Value = 5.103156566619873
# Epoch # 1, Time Step # 71, Loss Value = 5.041012287139893
# Epoch # 1, Time Step # 72, Loss Value = 4.878809928894043
# Epoch # 1, Time Step # 73, Loss Value = 5.349209308624268
# Epoch # 1, Time Step # 74, Loss Value = 5.187443733215332
# Epoch # 1, Time Step # 75, Loss Value = 5.09201192855835
# Epoch # 1, Time Step # 76, Loss Value = 5.240598201751709
# Epoch # 1, Time Step # 77, Loss Value = 5.107203960418701
# Epoch # 1, Time Step # 78, Loss Value = 4.693243026733398
# Epoch # 1, Time Step # 79, Loss Value = 5.14840841293335
# Epoch # 1, Time Step # 80, Loss Value = 4.42786979675293
# Epoch # 1, Time Step # 81, Loss Value = 4.907299041748047
# Epoch # 1, Time Step # 82, Loss Value = 4.507448673248291
# Epoch # 1, Time Step # 83, Loss Value = 4.778543949127197
# Epoch # 1, Time Step # 84, Loss Value = 4.534576892852783
# Epoch # 1, Time Step # 85, Loss Value = 4.468466281890869
# Epoch # 1, Time Step # 86, Loss Value = 4.178924083709717
# Epoch # 1, Time Step # 87, Loss Value = 4.316856384277344
# Epoch # 1, Time Step # 88, Loss Value = 4.523724555969238
# Epoch # 1, Time Step # 89, Loss Value = 4.431937217712402
# Epoch # 1, Time Step # 90, Loss Value = 3.7918171882629395
# Epoch # 1, Time Step # 91, Loss Value = 4.178567409515381
# Epoch # 1, Time Step # 92, Loss Value = 5.091408729553223
# Epoch # 1, Time Step # 93, Loss Value = 4.0113935470581055
# Epoch # 1, Time Step # 94, Loss Value = 5.026442050933838
# Epoch # 1, Time Step # 95, Loss Value = 6.249667644500732
# Epoch # 1, Time Step # 96, Loss Value = 6.383757591247559
# Epoch # 1, Time Step # 97, Loss Value = 5.037697792053223
# Epoch # 1, Time Step # 98, Loss Value = 4.386660575866699
# Epoch # 1, Time Step # 99, Loss Value = 4.570615768432617
# Epoch # 1, Time Step # 100, Loss Value = 4.749366760253906
# Epoch # 1, Time Step # 101, Loss Value = 4.008800983428955
# Epoch # 1, Time Step # 102, Loss Value = 3.8956010341644287
# Epoch # 1, Time Step # 103, Loss Value = 4.427130699157715
# Epoch # 1, Time Step # 104, Loss Value = 4.383925914764404
# Epoch # 1, Time Step # 105, Loss Value = 4.331011772155762
# Epoch # 1, Time Step # 106, Loss Value = 4.306551933288574
# Epoch # 1, Time Step # 107, Loss Value = 3.935077667236328
# Epoch # 1, Time Step # 108, Loss Value = 4.246147155761719
# Epoch # 1, Time Step # 109, Loss Value = 3.9546821117401123
# Epoch # 1, Time Step # 110, Loss Value = 4.156090259552002
# Epoch # 1, Time Step # 111, Loss Value = 5.229429244995117
# Epoch # 1, Time Step # 112, Loss Value = 5.709007740020752
# Epoch # 1, Time Step # 113, Loss Value = 5.12648868560791
# Epoch # 1, Time Step # 114, Loss Value = 4.6159348487854
# Epoch # 1, Time Step # 115, Loss Value = 4.595302581787109
# Epoch # 1, Time Step # 116, Loss Value = 4.8013691902160645
# Epoch # 1, Time Step # 117, Loss Value = 4.580509185791016
# Epoch # 1, Time Step # 118, Loss Value = 4.356290340423584
# Epoch # 1, Time Step # 119, Loss Value = 4.790782928466797
# Epoch # 1, Time Step # 120, Loss Value = 5.1775665283203125
# Epoch # 1, Time Step # 121, Loss Value = 4.182163715362549
# Epoch # 1, Time Step # 122, Loss Value = 4.487969398498535
# Epoch # 1, Time Step # 123, Loss Value = 4.446650505065918
# Epoch # 1, Time Step # 124, Loss Value = 4.296017646789551
# Epoch # 1, Time Step # 125, Loss Value = 4.428411960601807
# Epoch # 1, Time Step # 126, Loss Value = 4.359414100646973
# Epoch # 1, Time Step # 127, Loss Value = 4.458079814910889
# Epoch # 1, Time Step # 128, Loss Value = 5.001424312591553
# Epoch # 1, Time Step # 129, Loss Value = 5.184027194976807
# Epoch # 1, Time Step # 130, Loss Value = 5.126279830932617
# Epoch # 1, Time Step # 131, Loss Value = 4.517098426818848
# Epoch # 1, Time Step # 132, Loss Value = 4.190691947937012
# Epoch # 1, Time Step # 133, Loss Value = 3.9696154594421387
# Epoch # 1, Time Step # 134, Loss Value = 4.447646141052246
# Epoch # 1, Time Step # 135, Loss Value = 4.184830665588379
# Epoch # 1, Time Step # 136, Loss Value = 4.435161590576172
# Epoch # 1, Time Step # 137, Loss Value = 4.565730094909668
# Epoch # 1, Time Step # 138, Loss Value = 4.132030487060547
# Epoch # 1, Time Step # 139, Loss Value = 4.781887054443359
# Epoch # 1, Time Step # 140, Loss Value = 4.509045124053955
# Epoch # 1, Time Step # 141, Loss Value = 4.223413467407227
# Epoch # 1, Time Step # 142, Loss Value = 4.071617603302002
# Epoch # 1, Time Step # 143, Loss Value = 4.409177303314209
# Epoch # 1, Time Step # 144, Loss Value = 4.069652557373047
# Epoch # 1, Time Step # 145, Loss Value = 4.035736083984375
# Epoch # 1, Time Step # 146, Loss Value = 3.90732479095459
# Epoch # 1, Time Step # 147, Loss Value = 4.433428764343262
# Epoch # 1, Time Step # 148, Loss Value = 4.276318073272705
# Epoch # 1, Time Step # 149, Loss Value = 4.46558141708374
# Epoch # 1, Time Step # 150, Loss Value = 4.268334865570068
# Epoch # 1, Time Step # 151, Loss Value = 4.306725978851318
# Epoch # 1, Time Step # 152, Loss Value = 4.539160251617432
# Epoch # 1, Time Step # 153, Loss Value = 4.202327251434326
# Epoch # 1, Time Step # 154, Loss Value = 4.162912368774414
# Epoch # 1, Time Step # 155, Loss Value = 4.410595893859863
# Epoch # 1, Time Step # 156, Loss Value = 4.3837409019470215
# Epoch # 1, Time Step # 157, Loss Value = 4.367074966430664
# Epoch # 1, Time Step # 158, Loss Value = 4.344542503356934
# Epoch # 1, Time Step # 159, Loss Value = 5.294431209564209
# Epoch # 1, Time Step # 160, Loss Value = 5.064948558807373
# Epoch # 1, Time Step # 161, Loss Value = 5.275484561920166
# Epoch # 1, Time Step # 162, Loss Value = 5.056135654449463
# Epoch # 1, Time Step # 163, Loss Value = 4.831113815307617
# Epoch # 1, Time Step # 164, Loss Value = 4.854276180267334
# Epoch # 1, Time Step # 165, Loss Value = 4.583285331726074
# Epoch # 1, Time Step # 166, Loss Value = 4.405109405517578
# Epoch # 1, Time Step # 167, Loss Value = 4.919457912445068
# Epoch # 1, Time Step # 168, Loss Value = 4.657554626464844
# Epoch # 1, Time Step # 169, Loss Value = 4.678037166595459
# Epoch # 1, Time Step # 170, Loss Value = 4.796028137207031
# Epoch # 1, Time Step # 171, Loss Value = 4.782235622406006
# Epoch # 1, Time Step # 172, Loss Value = 5.228355884552002
# Epoch # 1, Time Step # 173, Loss Value = 4.877560615539551
# Epoch # 1, Time Step # 174, Loss Value = 5.078176498413086
# Epoch # 1, Time Step # 175, Loss Value = 4.526763916015625
# Epoch # 1, Time Step # 176, Loss Value = 4.403099536895752
# Epoch # 1, Time Step # 177, Loss Value = 4.419915676116943
# Epoch # 1, Time Step # 178, Loss Value = 4.673460006713867
# Epoch # 1, Time Step # 179, Loss Value = 4.487431049346924
# Epoch # 1, Time Step # 180, Loss Value = 4.71522855758667
# Epoch # 1, Time Step # 181, Loss Value = 4.482447624206543
# Epoch # 1, Time Step # 182, Loss Value = 4.284112453460693
# Epoch # 1, Time Step # 183, Loss Value = 4.3919219970703125
# Epoch # 1, Time Step # 184, Loss Value = 4.459354877471924
# Epoch # 1, Time Step # 185, Loss Value = 4.3288044929504395
# Epoch # 1, Time Step # 186, Loss Value = 4.490522384643555
# Epoch # 1, Time Step # 187, Loss Value = 5.522750377655029
# Epoch # 1, Time Step # 188, Loss Value = 4.4301371574401855
# Epoch # 1, Time Step # 189, Loss Value = 4.471078395843506
# Epoch # 1, Time Step # 190, Loss Value = 4.421620845794678
# Epoch # 1, Time Step # 191, Loss Value = 4.4585676193237305
# Epoch # 1, Time Step # 192, Loss Value = 4.552402496337891
# Epoch # 1, Time Step # 193, Loss Value = 4.148010730743408
# Epoch # 1, Time Step # 194, Loss Value = 4.447843551635742
# Epoch # 1, Time Step # 195, Loss Value = 4.734303951263428
# Epoch # 1, Time Step # 196, Loss Value = 4.817584991455078
# Epoch # 1, Time Step # 197, Loss Value = 4.672151565551758
# Epoch # 1, Time Step # 198, Loss Value = 4.602070331573486
# Epoch # 1, Time Step # 199, Loss Value = 4.619855880737305
# Epoch # 2, Time Step # 0, Loss Value = 4.5198163986206055
# Epoch # 2, Time Step # 1, Loss Value = 4.869372844696045
# Epoch # 2, Time Step # 2, Loss Value = 4.827663898468018
# Epoch # 2, Time Step # 3, Loss Value = 5.28465461730957
# Epoch # 2, Time Step # 4, Loss Value = 5.278020858764648
# Epoch # 2, Time Step # 5, Loss Value = 4.996679306030273
# Epoch # 2, Time Step # 6, Loss Value = 5.213915824890137
# Epoch # 2, Time Step # 7, Loss Value = 5.118410587310791
# Epoch # 2, Time Step # 8, Loss Value = 5.256045341491699
# Epoch # 2, Time Step # 9, Loss Value = 5.2851948738098145
# Epoch # 2, Time Step # 10, Loss Value = 4.8469085693359375
# Epoch # 2, Time Step # 11, Loss Value = 5.186611175537109
# Epoch # 2, Time Step # 12, Loss Value = 4.7768049240112305
# Epoch # 2, Time Step # 13, Loss Value = 5.294435501098633
# Epoch # 2, Time Step # 14, Loss Value = 5.168619632720947
# Epoch # 2, Time Step # 15, Loss Value = 5.1665449142456055
# Epoch # 2, Time Step # 16, Loss Value = 4.915410995483398
# Epoch # 2, Time Step # 17, Loss Value = 5.087271690368652
# Epoch # 2, Time Step # 18, Loss Value = 4.892638206481934
# Epoch # 2, Time Step # 19, Loss Value = 5.124733924865723
# Epoch # 2, Time Step # 20, Loss Value = 5.025197505950928
# Epoch # 2, Time Step # 21, Loss Value = 4.853099822998047
# Epoch # 2, Time Step # 22, Loss Value = 4.574275016784668
# Epoch # 2, Time Step # 23, Loss Value = 4.898329257965088
# Epoch # 2, Time Step # 24, Loss Value = 5.265013694763184
# Epoch # 2, Time Step # 25, Loss Value = 5.023977756500244
# Epoch # 2, Time Step # 26, Loss Value = 4.946121692657471
# Epoch # 2, Time Step # 27, Loss Value = 5.027400493621826
# Epoch # 2, Time Step # 28, Loss Value = 4.786238193511963
# Epoch # 2, Time Step # 29, Loss Value = 4.854470252990723
# Epoch # 2, Time Step # 30, Loss Value = 4.70526123046875
# Epoch # 2, Time Step # 31, Loss Value = 4.65287446975708
# Epoch # 2, Time Step # 32, Loss Value = 4.621970176696777
# Epoch # 2, Time Step # 33, Loss Value = 4.684102535247803
# Epoch # 2, Time Step # 34, Loss Value = 4.983174800872803
# Epoch # 2, Time Step # 35, Loss Value = 5.187909126281738
# Epoch # 2, Time Step # 36, Loss Value = 5.256800651550293
# Epoch # 2, Time Step # 37, Loss Value = 5.178201198577881
# Epoch # 2, Time Step # 38, Loss Value = 5.078165531158447
# Epoch # 2, Time Step # 39, Loss Value = 5.1838250160217285
# Epoch # 2, Time Step # 40, Loss Value = 4.906883716583252
# Epoch # 2, Time Step # 41, Loss Value = 4.994630813598633
# Epoch # 2, Time Step # 42, Loss Value = 4.670863628387451
# Epoch # 2, Time Step # 43, Loss Value = 4.925523281097412
# Epoch # 2, Time Step # 44, Loss Value = 4.648586273193359
# Epoch # 2, Time Step # 45, Loss Value = 4.720020771026611
# Epoch # 2, Time Step # 46, Loss Value = 4.9892578125
# Epoch # 2, Time Step # 47, Loss Value = 4.600395202636719
# Epoch # 2, Time Step # 48, Loss Value = 4.828968524932861
# Epoch # 2, Time Step # 49, Loss Value = 4.721301078796387
# Epoch # 2, Time Step # 50, Loss Value = 4.661360263824463
# Epoch # 2, Time Step # 51, Loss Value = 4.8644819259643555
# Epoch # 2, Time Step # 52, Loss Value = 5.039741039276123
# Epoch # 2, Time Step # 53, Loss Value = 4.841057777404785
# Epoch # 2, Time Step # 54, Loss Value = 5.082134246826172
# Epoch # 2, Time Step # 55, Loss Value = 5.0679240226745605
# Epoch # 2, Time Step # 56, Loss Value = 4.628874778747559
# Epoch # 2, Time Step # 57, Loss Value = 4.841145038604736
# Epoch # 2, Time Step # 58, Loss Value = 4.8458333015441895
# Epoch # 2, Time Step # 59, Loss Value = 4.330330848693848
# Epoch # 2, Time Step # 60, Loss Value = 4.3667097091674805
# Epoch # 2, Time Step # 61, Loss Value = 4.50779390335083
# Epoch # 2, Time Step # 62, Loss Value = 5.020873546600342
# Epoch # 2, Time Step # 63, Loss Value = 5.180841445922852
# Epoch # 2, Time Step # 64, Loss Value = 4.63590669631958
# Epoch # 2, Time Step # 65, Loss Value = 4.9219970703125
# Epoch # 2, Time Step # 66, Loss Value = 5.141354560852051
# Epoch # 2, Time Step # 67, Loss Value = 5.386680603027344
# Epoch # 2, Time Step # 68, Loss Value = 4.836637020111084
# Epoch # 2, Time Step # 69, Loss Value = 5.466117858886719
# Epoch # 2, Time Step # 70, Loss Value = 4.878047466278076
# Epoch # 2, Time Step # 71, Loss Value = 4.776927947998047
# Epoch # 2, Time Step # 72, Loss Value = 4.6295166015625
# Epoch # 2, Time Step # 73, Loss Value = 5.1023335456848145
# Epoch # 2, Time Step # 74, Loss Value = 4.952915668487549
# Epoch # 2, Time Step # 75, Loss Value = 4.8734893798828125
# Epoch # 2, Time Step # 76, Loss Value = 4.9803972244262695
# Epoch # 2, Time Step # 77, Loss Value = 4.853487491607666
# Epoch # 2, Time Step # 78, Loss Value = 4.432861804962158
# Epoch # 2, Time Step # 79, Loss Value = 4.898552417755127
# Epoch # 2, Time Step # 80, Loss Value = 4.144376277923584
# Epoch # 2, Time Step # 81, Loss Value = 4.643413543701172
# Epoch # 2, Time Step # 82, Loss Value = 4.302243709564209
# Epoch # 2, Time Step # 83, Loss Value = 4.533345699310303
# Epoch # 2, Time Step # 84, Loss Value = 4.257816314697266
# Epoch # 2, Time Step # 85, Loss Value = 4.293983459472656
# Epoch # 2, Time Step # 86, Loss Value = 3.969236135482788
# Epoch # 2, Time Step # 87, Loss Value = 4.136658668518066
# Epoch # 2, Time Step # 88, Loss Value = 4.320943355560303
# Epoch # 2, Time Step # 89, Loss Value = 4.18301248550415
# Epoch # 2, Time Step # 90, Loss Value = 3.498589038848877
# Epoch # 2, Time Step # 91, Loss Value = 3.9689416885375977
# Epoch # 2, Time Step # 92, Loss Value = 4.895434856414795
# Epoch # 2, Time Step # 93, Loss Value = 3.8114302158355713
# Epoch # 2, Time Step # 94, Loss Value = 4.811428070068359
# Epoch # 2, Time Step # 95, Loss Value = 6.035006523132324
# Epoch # 2, Time Step # 96, Loss Value = 6.199997425079346
# Epoch # 2, Time Step # 97, Loss Value = 4.812153339385986
# Epoch # 2, Time Step # 98, Loss Value = 4.167450428009033
# Epoch # 2, Time Step # 99, Loss Value = 4.346526145935059
# Epoch # 2, Time Step # 100, Loss Value = 4.529978275299072
# Epoch # 2, Time Step # 101, Loss Value = 3.796595573425293
# Epoch # 2, Time Step # 102, Loss Value = 3.6861984729766846
# Epoch # 2, Time Step # 103, Loss Value = 4.233009338378906
# Epoch # 2, Time Step # 104, Loss Value = 4.143407821655273
# Epoch # 2, Time Step # 105, Loss Value = 4.132027626037598
# Epoch # 2, Time Step # 106, Loss Value = 4.0581889152526855
# Epoch # 2, Time Step # 107, Loss Value = 3.736259937286377
# Epoch # 2, Time Step # 108, Loss Value = 4.087924957275391
# Epoch # 2, Time Step # 109, Loss Value = 3.7812838554382324
# Epoch # 2, Time Step # 110, Loss Value = 3.9447274208068848
# Epoch # 2, Time Step # 111, Loss Value = 5.005102157592773
# Epoch # 2, Time Step # 112, Loss Value = 5.478117942810059
# Epoch # 2, Time Step # 113, Loss Value = 4.885797500610352
# Epoch # 2, Time Step # 114, Loss Value = 4.338775634765625
# Epoch # 2, Time Step # 115, Loss Value = 4.356484889984131
# Epoch # 2, Time Step # 116, Loss Value = 4.506979465484619
# Epoch # 2, Time Step # 117, Loss Value = 4.351714611053467
# Epoch # 2, Time Step # 118, Loss Value = 4.127655982971191
# Epoch # 2, Time Step # 119, Loss Value = 4.535343647003174
# Epoch # 2, Time Step # 120, Loss Value = 4.941800594329834
# Epoch # 2, Time Step # 121, Loss Value = 3.9309048652648926
# Epoch # 2, Time Step # 122, Loss Value = 4.2675957679748535
# Epoch # 2, Time Step # 123, Loss Value = 4.1926774978637695
# Epoch # 2, Time Step # 124, Loss Value = 4.073629856109619
# Epoch # 2, Time Step # 125, Loss Value = 4.187786102294922
# Epoch # 2, Time Step # 126, Loss Value = 4.096341133117676
# Epoch # 2, Time Step # 127, Loss Value = 4.18406343460083
# Epoch # 2, Time Step # 128, Loss Value = 4.787813663482666
# Epoch # 2, Time Step # 129, Loss Value = 4.944668292999268
# Epoch # 2, Time Step # 130, Loss Value = 4.905694961547852
# Epoch # 2, Time Step # 131, Loss Value = 4.2531938552856445
# Epoch # 2, Time Step # 132, Loss Value = 3.97489857673645
# Epoch # 2, Time Step # 133, Loss Value = 3.7633368968963623
# Epoch # 2, Time Step # 134, Loss Value = 4.223472595214844
# Epoch # 2, Time Step # 135, Loss Value = 3.915389060974121
# Epoch # 2, Time Step # 136, Loss Value = 4.172823905944824
# Epoch # 2, Time Step # 137, Loss Value = 4.313485145568848
# Epoch # 2, Time Step # 138, Loss Value = 3.906445026397705
# Epoch # 2, Time Step # 139, Loss Value = 4.528324127197266
# Epoch # 2, Time Step # 140, Loss Value = 4.261593818664551
# Epoch # 2, Time Step # 141, Loss Value = 3.971604585647583
# Epoch # 2, Time Step # 142, Loss Value = 3.864673137664795
# Epoch # 2, Time Step # 143, Loss Value = 4.1747260093688965
# Epoch # 2, Time Step # 144, Loss Value = 3.8384387493133545
# Epoch # 2, Time Step # 145, Loss Value = 3.783987522125244
# Epoch # 2, Time Step # 146, Loss Value = 3.6514222621917725
# Epoch # 2, Time Step # 147, Loss Value = 4.159468173980713
# Epoch # 2, Time Step # 148, Loss Value = 4.02853536605835
# Epoch # 2, Time Step # 149, Loss Value = 4.2122578620910645
# Epoch # 2, Time Step # 150, Loss Value = 4.014191150665283
# Epoch # 2, Time Step # 151, Loss Value = 4.008452892303467
# Epoch # 2, Time Step # 152, Loss Value = 4.275742053985596
# Epoch # 2, Time Step # 153, Loss Value = 3.936049222946167
# Epoch # 2, Time Step # 154, Loss Value = 3.926565647125244
# Epoch # 2, Time Step # 155, Loss Value = 4.194952011108398
# Epoch # 2, Time Step # 156, Loss Value = 4.123587131500244
# Epoch # 2, Time Step # 157, Loss Value = 4.150355815887451
# Epoch # 2, Time Step # 158, Loss Value = 4.10280179977417
# Epoch # 2, Time Step # 159, Loss Value = 5.0721635818481445
# Epoch # 2, Time Step # 160, Loss Value = 4.835315704345703
# Epoch # 2, Time Step # 161, Loss Value = 5.0075578689575195
# Epoch # 2, Time Step # 162, Loss Value = 4.720075607299805
# Epoch # 2, Time Step # 163, Loss Value = 4.603293418884277
# Epoch # 2, Time Step # 164, Loss Value = 4.598997592926025
# Epoch # 2, Time Step # 165, Loss Value = 4.325888633728027
# Epoch # 2, Time Step # 166, Loss Value = 4.129628658294678
# Epoch # 2, Time Step # 167, Loss Value = 4.672876834869385
# Epoch # 2, Time Step # 168, Loss Value = 4.476724624633789
# Epoch # 2, Time Step # 169, Loss Value = 4.419704914093018
# Epoch # 2, Time Step # 170, Loss Value = 4.542492866516113
# Epoch # 2, Time Step # 171, Loss Value = 4.509736061096191
# Epoch # 2, Time Step # 172, Loss Value = 4.999635219573975
# Epoch # 2, Time Step # 173, Loss Value = 4.639294147491455
# Epoch # 2, Time Step # 174, Loss Value = 4.836631774902344
# Epoch # 2, Time Step # 175, Loss Value = 4.252191543579102
# Epoch # 2, Time Step # 176, Loss Value = 4.170634746551514
# Epoch # 2, Time Step # 177, Loss Value = 4.159297943115234
# Epoch # 2, Time Step # 178, Loss Value = 4.388477325439453
# Epoch # 2, Time Step # 179, Loss Value = 4.22893762588501
# Epoch # 2, Time Step # 180, Loss Value = 4.379573822021484
# Epoch # 2, Time Step # 181, Loss Value = 4.192742347717285
# Epoch # 2, Time Step # 182, Loss Value = 4.021868705749512
# Epoch # 2, Time Step # 183, Loss Value = 4.167442321777344
# Epoch # 2, Time Step # 184, Loss Value = 4.214768409729004
# Epoch # 2, Time Step # 185, Loss Value = 4.051836013793945
# Epoch # 2, Time Step # 186, Loss Value = 4.222896575927734
# Epoch # 2, Time Step # 187, Loss Value = 5.263463020324707
# Epoch # 2, Time Step # 188, Loss Value = 4.210780143737793
# Epoch # 2, Time Step # 189, Loss Value = 4.21058988571167
# Epoch # 2, Time Step # 190, Loss Value = 4.168537616729736
# Epoch # 2, Time Step # 191, Loss Value = 4.228137493133545
# Epoch # 2, Time Step # 192, Loss Value = 4.256963729858398
# Epoch # 2, Time Step # 193, Loss Value = 3.8963849544525146
# Epoch # 2, Time Step # 194, Loss Value = 4.1904425621032715
# Epoch # 2, Time Step # 195, Loss Value = 4.531426429748535
# Epoch # 2, Time Step # 196, Loss Value = 4.561906337738037
# Epoch # 2, Time Step # 197, Loss Value = 4.468748569488525
# Epoch # 2, Time Step # 198, Loss Value = 4.361173629760742
# Epoch # 2, Time Step # 199, Loss Value = 4.411027908325195
# Epoch # 3, Time Step # 0, Loss Value = 4.320702075958252
# Epoch # 3, Time Step # 1, Loss Value = 4.652276992797852
# Epoch # 3, Time Step # 2, Loss Value = 4.625077247619629
# Epoch # 3, Time Step # 3, Loss Value = 5.0735039710998535
# Epoch # 3, Time Step # 4, Loss Value = 5.066500186920166
# Epoch # 3, Time Step # 5, Loss Value = 4.7659807205200195
# Epoch # 3, Time Step # 6, Loss Value = 5.022429466247559
# Epoch # 3, Time Step # 7, Loss Value = 4.885894775390625
# Epoch # 3, Time Step # 8, Loss Value = 5.065805435180664
# Epoch # 3, Time Step # 9, Loss Value = 5.094119071960449
# Epoch # 3, Time Step # 10, Loss Value = 4.631608486175537
# Epoch # 3, Time Step # 11, Loss Value = 4.992613315582275
# Epoch # 3, Time Step # 12, Loss Value = 4.55963659286499
# Epoch # 3, Time Step # 13, Loss Value = 5.102453708648682
# Epoch # 3, Time Step # 14, Loss Value = 4.9658989906311035
# Epoch # 3, Time Step # 15, Loss Value = 4.969577312469482
# Epoch # 3, Time Step # 16, Loss Value = 4.725002765655518
# Epoch # 3, Time Step # 17, Loss Value = 4.897201061248779
# Epoch # 3, Time Step # 18, Loss Value = 4.71472692489624
# Epoch # 3, Time Step # 19, Loss Value = 4.939774990081787
# Epoch # 3, Time Step # 20, Loss Value = 4.8170976638793945
# Epoch # 3, Time Step # 21, Loss Value = 4.654755592346191
# Epoch # 3, Time Step # 22, Loss Value = 4.337924480438232
# Epoch # 3, Time Step # 23, Loss Value = 4.653995990753174
# Epoch # 3, Time Step # 24, Loss Value = 5.061370372772217
# Epoch # 3, Time Step # 25, Loss Value = 4.835791110992432
# Epoch # 3, Time Step # 26, Loss Value = 4.766079425811768
# Epoch # 3, Time Step # 27, Loss Value = 4.804938316345215
# Epoch # 3, Time Step # 28, Loss Value = 4.569425582885742
# Epoch # 3, Time Step # 29, Loss Value = 4.6489973068237305
# Epoch # 3, Time Step # 30, Loss Value = 4.486796855926514
# Epoch # 3, Time Step # 31, Loss Value = 4.405876636505127
# Epoch # 3, Time Step # 32, Loss Value = 4.407498359680176
# Epoch # 3, Time Step # 33, Loss Value = 4.464283466339111
# Epoch # 3, Time Step # 34, Loss Value = 4.801354885101318
# Epoch # 3, Time Step # 35, Loss Value = 4.980250358581543
# Epoch # 3, Time Step # 36, Loss Value = 5.065189361572266
# Epoch # 3, Time Step # 37, Loss Value = 4.981856346130371
# Epoch # 3, Time Step # 38, Loss Value = 4.875026226043701
# Epoch # 3, Time Step # 39, Loss Value = 5.0080485343933105
# Epoch # 3, Time Step # 40, Loss Value = 4.732224464416504
# Epoch # 3, Time Step # 41, Loss Value = 4.812628746032715
# Epoch # 3, Time Step # 42, Loss Value = 4.510146141052246
# Epoch # 3, Time Step # 43, Loss Value = 4.7467546463012695
# Epoch # 3, Time Step # 44, Loss Value = 4.454216003417969
# Epoch # 3, Time Step # 45, Loss Value = 4.529844760894775
# Epoch # 3, Time Step # 46, Loss Value = 4.803319454193115
# Epoch # 3, Time Step # 47, Loss Value = 4.397346019744873
# Epoch # 3, Time Step # 48, Loss Value = 4.6229567527771
# Epoch # 3, Time Step # 49, Loss Value = 4.533413410186768
# Epoch # 3, Time Step # 50, Loss Value = 4.473234176635742
# Epoch # 3, Time Step # 51, Loss Value = 4.695618629455566
# Epoch # 3, Time Step # 52, Loss Value = 4.842781066894531
# Epoch # 3, Time Step # 53, Loss Value = 4.638035297393799
# Epoch # 3, Time Step # 54, Loss Value = 4.887357234954834
# Epoch # 3, Time Step # 55, Loss Value = 4.870832443237305
# Epoch # 3, Time Step # 56, Loss Value = 4.4171977043151855
# Epoch # 3, Time Step # 57, Loss Value = 4.643284320831299
# Epoch # 3, Time Step # 58, Loss Value = 4.627171516418457
# Epoch # 3, Time Step # 59, Loss Value = 4.1385908126831055
# Epoch # 3, Time Step # 60, Loss Value = 4.133944988250732
# Epoch # 3, Time Step # 61, Loss Value = 4.313872337341309
# Epoch # 3, Time Step # 62, Loss Value = 4.809998512268066
# Epoch # 3, Time Step # 63, Loss Value = 4.9849677085876465
# Epoch # 3, Time Step # 64, Loss Value = 4.429186820983887
# Epoch # 3, Time Step # 65, Loss Value = 4.70723295211792
# Epoch # 3, Time Step # 66, Loss Value = 4.9469428062438965
# Epoch # 3, Time Step # 67, Loss Value = 5.202088832855225
# Epoch # 3, Time Step # 68, Loss Value = 4.606650352478027
# Epoch # 3, Time Step # 69, Loss Value = 5.3058061599731445
# Epoch # 3, Time Step # 70, Loss Value = 4.67421817779541
# Epoch # 3, Time Step # 71, Loss Value = 4.5688629150390625
# Epoch # 3, Time Step # 72, Loss Value = 4.411454677581787
# Epoch # 3, Time Step # 73, Loss Value = 4.876054286956787
# Epoch # 3, Time Step # 74, Loss Value = 4.729940414428711
# Epoch # 3, Time Step # 75, Loss Value = 4.668458938598633
# Epoch # 3, Time Step # 76, Loss Value = 4.748538017272949
# Epoch # 3, Time Step # 77, Loss Value = 4.623777866363525
# Epoch # 3, Time Step # 78, Loss Value = 4.19281005859375
# Epoch # 3, Time Step # 79, Loss Value = 4.66649055480957
# Epoch # 3, Time Step # 80, Loss Value = 3.896127223968506
# Epoch # 3, Time Step # 81, Loss Value = 4.414351940155029
# Epoch # 3, Time Step # 82, Loss Value = 4.12186861038208
# Epoch # 3, Time Step # 83, Loss Value = 4.29816198348999
# Epoch # 3, Time Step # 84, Loss Value = 4.021150588989258
# Epoch # 3, Time Step # 85, Loss Value = 4.1280317306518555
# Epoch # 3, Time Step # 86, Loss Value = 3.7806408405303955
# Epoch # 3, Time Step # 87, Loss Value = 3.9685821533203125
# Epoch # 3, Time Step # 88, Loss Value = 4.144287586212158
# Epoch # 3, Time Step # 89, Loss Value = 3.950498342514038
# Epoch # 3, Time Step # 90, Loss Value = 3.218513250350952
# Epoch # 3, Time Step # 91, Loss Value = 3.7705342769622803
# Epoch # 3, Time Step # 92, Loss Value = 4.696063041687012
# Epoch # 3, Time Step # 93, Loss Value = 3.609984874725342
# Epoch # 3, Time Step # 94, Loss Value = 4.622734546661377
# Epoch # 3, Time Step # 95, Loss Value = 5.8658599853515625
# Epoch # 3, Time Step # 96, Loss Value = 6.053124904632568
# Epoch # 3, Time Step # 97, Loss Value = 4.604957580566406
# Epoch # 3, Time Step # 98, Loss Value = 3.9937381744384766
# Epoch # 3, Time Step # 99, Loss Value = 4.151663780212402
# Epoch # 3, Time Step # 100, Loss Value = 4.340546131134033
# Epoch # 3, Time Step # 101, Loss Value = 3.604147434234619
# Epoch # 3, Time Step # 102, Loss Value = 3.489727258682251
# Epoch # 3, Time Step # 103, Loss Value = 4.031135082244873
# Epoch # 3, Time Step # 104, Loss Value = 3.914475679397583
# Epoch # 3, Time Step # 105, Loss Value = 3.94415020942688
# Epoch # 3, Time Step # 106, Loss Value = 3.8279809951782227
# Epoch # 3, Time Step # 107, Loss Value = 3.555335283279419
# Epoch # 3, Time Step # 108, Loss Value = 3.9284088611602783
# Epoch # 3, Time Step # 109, Loss Value = 3.634307384490967
# Epoch # 3, Time Step # 110, Loss Value = 3.7622036933898926
# Epoch # 3, Time Step # 111, Loss Value = 4.815245151519775
# Epoch # 3, Time Step # 112, Loss Value = 5.24923849105835
# Epoch # 3, Time Step # 113, Loss Value = 4.675917625427246
# Epoch # 3, Time Step # 114, Loss Value = 4.081483840942383
# Epoch # 3, Time Step # 115, Loss Value = 4.1399641036987305
# Epoch # 3, Time Step # 116, Loss Value = 4.23736572265625
# Epoch # 3, Time Step # 117, Loss Value = 4.1416096687316895
# Epoch # 3, Time Step # 118, Loss Value = 3.9158856868743896
# Epoch # 3, Time Step # 119, Loss Value = 4.315852165222168
# Epoch # 3, Time Step # 120, Loss Value = 4.718702793121338
# Epoch # 3, Time Step # 121, Loss Value = 3.712040662765503
# Epoch # 3, Time Step # 122, Loss Value = 4.083436489105225
# Epoch # 3, Time Step # 123, Loss Value = 3.9657816886901855
# Epoch # 3, Time Step # 124, Loss Value = 3.869988441467285
# Epoch # 3, Time Step # 125, Loss Value = 3.9912827014923096
# Epoch # 3, Time Step # 126, Loss Value = 3.866495370864868
# Epoch # 3, Time Step # 127, Loss Value = 3.9301609992980957
# Epoch # 3, Time Step # 128, Loss Value = 4.586084842681885
# Epoch # 3, Time Step # 129, Loss Value = 4.725640773773193
# Epoch # 3, Time Step # 130, Loss Value = 4.695347309112549
# Epoch # 3, Time Step # 131, Loss Value = 4.037265777587891
# Epoch # 3, Time Step # 132, Loss Value = 3.7905304431915283
# Epoch # 3, Time Step # 133, Loss Value = 3.597038984298706
# Epoch # 3, Time Step # 134, Loss Value = 4.026855945587158
# Epoch # 3, Time Step # 135, Loss Value = 3.6877055168151855
# Epoch # 3, Time Step # 136, Loss Value = 3.9487104415893555
# Epoch # 3, Time Step # 137, Loss Value = 4.08878755569458
# Epoch # 3, Time Step # 138, Loss Value = 3.722317695617676
# Epoch # 3, Time Step # 139, Loss Value = 4.317224502563477
# Epoch # 3, Time Step # 140, Loss Value = 4.052137851715088
# Epoch # 3, Time Step # 141, Loss Value = 3.7680935859680176
# Epoch # 3, Time Step # 142, Loss Value = 3.678154706954956
# Epoch # 3, Time Step # 143, Loss Value = 3.9690208435058594
# Epoch # 3, Time Step # 144, Loss Value = 3.6389260292053223
# Epoch # 3, Time Step # 145, Loss Value = 3.583559989929199
# Epoch # 3, Time Step # 146, Loss Value = 3.4335920810699463
# Epoch # 3, Time Step # 147, Loss Value = 3.95682954788208
# Epoch # 3, Time Step # 148, Loss Value = 3.8219120502471924
# Epoch # 3, Time Step # 149, Loss Value = 4.003574848175049
# Epoch # 3, Time Step # 150, Loss Value = 3.787949800491333
# Epoch # 3, Time Step # 151, Loss Value = 3.774219512939453
# Epoch # 3, Time Step # 152, Loss Value = 4.052895545959473
# Epoch # 3, Time Step # 153, Loss Value = 3.725217819213867
# Epoch # 3, Time Step # 154, Loss Value = 3.7529051303863525
# Epoch # 3, Time Step # 155, Loss Value = 4.019467353820801
# Epoch # 3, Time Step # 156, Loss Value = 3.9323740005493164
# Epoch # 3, Time Step # 157, Loss Value = 3.95855450630188
# Epoch # 3, Time Step # 158, Loss Value = 3.8962862491607666
# Epoch # 3, Time Step # 159, Loss Value = 4.854650020599365
# Epoch # 3, Time Step # 160, Loss Value = 4.641839027404785
# Epoch # 3, Time Step # 161, Loss Value = 4.789229393005371
# Epoch # 3, Time Step # 162, Loss Value = 4.4623260498046875
# Epoch # 3, Time Step # 163, Loss Value = 4.421335697174072
# Epoch # 3, Time Step # 164, Loss Value = 4.38020658493042
# Epoch # 3, Time Step # 165, Loss Value = 4.1092963218688965
# Epoch # 3, Time Step # 166, Loss Value = 3.9114227294921875
# Epoch # 3, Time Step # 167, Loss Value = 4.448768138885498
# Epoch # 3, Time Step # 168, Loss Value = 4.313886642456055
# Epoch # 3, Time Step # 169, Loss Value = 4.210221290588379
# Epoch # 3, Time Step # 170, Loss Value = 4.331430912017822
# Epoch # 3, Time Step # 171, Loss Value = 4.281490802764893
# Epoch # 3, Time Step # 172, Loss Value = 4.798777103424072
# Epoch # 3, Time Step # 173, Loss Value = 4.431257247924805
# Epoch # 3, Time Step # 174, Loss Value = 4.632070064544678
# Epoch # 3, Time Step # 175, Loss Value = 4.027525901794434
# Epoch # 3, Time Step # 176, Loss Value = 3.962493896484375
# Epoch # 3, Time Step # 177, Loss Value = 3.9468626976013184
# Epoch # 3, Time Step # 178, Loss Value = 4.150367736816406
# Epoch # 3, Time Step # 179, Loss Value = 4.014742374420166
# Epoch # 3, Time Step # 180, Loss Value = 4.102337837219238
# Epoch # 3, Time Step # 181, Loss Value = 3.958526849746704
# Epoch # 3, Time Step # 182, Loss Value = 3.799429178237915
# Epoch # 3, Time Step # 183, Loss Value = 3.978097915649414
# Epoch # 3, Time Step # 184, Loss Value = 4.005533218383789
# Epoch # 3, Time Step # 185, Loss Value = 3.8296942710876465
# Epoch # 3, Time Step # 186, Loss Value = 4.01321268081665
# Epoch # 3, Time Step # 187, Loss Value = 5.016139507293701
# Epoch # 3, Time Step # 188, Loss Value = 4.019534111022949
# Epoch # 3, Time Step # 189, Loss Value = 4.006837368011475
# Epoch # 3, Time Step # 190, Loss Value = 3.9638142585754395
# Epoch # 3, Time Step # 191, Loss Value = 4.025765419006348
# Epoch # 3, Time Step # 192, Loss Value = 4.027881145477295
# Epoch # 3, Time Step # 193, Loss Value = 3.696228265762329
# Epoch # 3, Time Step # 194, Loss Value = 3.981266498565674
# Epoch # 3, Time Step # 195, Loss Value = 4.350710391998291
# Epoch # 3, Time Step # 196, Loss Value = 4.345892906188965
# Epoch # 3, Time Step # 197, Loss Value = 4.292663097381592
# Epoch # 3, Time Step # 198, Loss Value = 4.173230171203613
# Epoch # 3, Time Step # 199, Loss Value = 4.235691070556641
# Epoch # 4, Time Step # 0, Loss Value = 4.146426200866699
# Epoch # 4, Time Step # 1, Loss Value = 4.472142219543457
# Epoch # 4, Time Step # 2, Loss Value = 4.445559501647949
# Epoch # 4, Time Step # 3, Loss Value = 4.886013031005859
# Epoch # 4, Time Step # 4, Loss Value = 4.886605739593506
# Epoch # 4, Time Step # 5, Loss Value = 4.547207355499268
# Epoch # 4, Time Step # 6, Loss Value = 4.846158981323242
# Epoch # 4, Time Step # 7, Loss Value = 4.681386470794678
# Epoch # 4, Time Step # 8, Loss Value = 4.886043548583984
# Epoch # 4, Time Step # 9, Loss Value = 4.919187545776367
# Epoch # 4, Time Step # 10, Loss Value = 4.442740440368652
# Epoch # 4, Time Step # 11, Loss Value = 4.825231552124023
# Epoch # 4, Time Step # 12, Loss Value = 4.382169723510742
# Epoch # 4, Time Step # 13, Loss Value = 4.924609184265137
# Epoch # 4, Time Step # 14, Loss Value = 4.783242702484131
# Epoch # 4, Time Step # 15, Loss Value = 4.8009843826293945
# Epoch # 4, Time Step # 16, Loss Value = 4.549563407897949
# Epoch # 4, Time Step # 17, Loss Value = 4.718334674835205
# Epoch # 4, Time Step # 18, Loss Value = 4.552250385284424
# Epoch # 4, Time Step # 19, Loss Value = 4.778685092926025
# ...
# Epoch # 248, Time Step # 145, Loss Value = 0.07849925011396408
# Epoch # 248, Time Step # 146, Loss Value = 0.22292476892471313
# Epoch # 248, Time Step # 147, Loss Value = 0.20111846923828125
# Epoch # 248, Time Step # 148, Loss Value = 0.08588334918022156
# Epoch # 248, Time Step # 149, Loss Value = 0.05166007578372955
# Epoch # 248, Time Step # 150, Loss Value = 0.08907956629991531
# Epoch # 248, Time Step # 151, Loss Value = 0.08900949358940125
# Epoch # 248, Time Step # 152, Loss Value = 0.10514796525239944
# Epoch # 248, Time Step # 153, Loss Value = 0.15232986211776733
# Epoch # 248, Time Step # 154, Loss Value = 0.09534018486738205
# Epoch # 248, Time Step # 155, Loss Value = 0.04040077328681946
# Epoch # 248, Time Step # 156, Loss Value = 0.1393730789422989
# Epoch # 248, Time Step # 157, Loss Value = 0.0993180200457573
# Epoch # 248, Time Step # 158, Loss Value = 0.06590480357408524
# Epoch # 248, Time Step # 159, Loss Value = 0.029768627136945724
# Epoch # 248, Time Step # 160, Loss Value = 0.03868456557393074
# Epoch # 248, Time Step # 161, Loss Value = 0.10035864263772964
# Epoch # 248, Time Step # 162, Loss Value = 0.07476014643907547
# Epoch # 248, Time Step # 163, Loss Value = 0.1275109052658081
# Epoch # 248, Time Step # 164, Loss Value = 0.2548266351222992
# Epoch # 248, Time Step # 165, Loss Value = 0.05403612181544304
# Epoch # 248, Time Step # 166, Loss Value = 0.07801864296197891
# Epoch # 248, Time Step # 167, Loss Value = 0.08381340652704239
# Epoch # 248, Time Step # 168, Loss Value = 0.012514748610556126
# Epoch # 248, Time Step # 169, Loss Value = 0.05624758079648018
# Epoch # 248, Time Step # 170, Loss Value = 0.05643198639154434
# Epoch # 248, Time Step # 171, Loss Value = 0.06137797236442566
# Epoch # 248, Time Step # 172, Loss Value = 0.012944391928613186
# Epoch # 248, Time Step # 173, Loss Value = 0.02253403142094612
# Epoch # 248, Time Step # 174, Loss Value = 0.026402372866868973
# Epoch # 248, Time Step # 175, Loss Value = 0.06759347021579742
# Epoch # 248, Time Step # 176, Loss Value = 0.059366460889577866
# Epoch # 248, Time Step # 177, Loss Value = 0.06650231778621674
# Epoch # 248, Time Step # 178, Loss Value = 0.07896248996257782
# Epoch # 248, Time Step # 179, Loss Value = 0.0472843311727047
# Epoch # 248, Time Step # 180, Loss Value = 0.050943274050951004
# Epoch # 248, Time Step # 181, Loss Value = 0.09001105278730392
# Epoch # 248, Time Step # 182, Loss Value = 0.10435350239276886
# Epoch # 248, Time Step # 183, Loss Value = 0.07804358750581741
# Epoch # 248, Time Step # 184, Loss Value = 0.07832217961549759
# Epoch # 248, Time Step # 185, Loss Value = 0.10014897584915161
# Epoch # 248, Time Step # 186, Loss Value = 0.0920647531747818
# Epoch # 248, Time Step # 187, Loss Value = 0.035731878131628036
# Epoch # 248, Time Step # 188, Loss Value = 0.08764687925577164
# Epoch # 248, Time Step # 189, Loss Value = 0.06023302301764488
# Epoch # 248, Time Step # 190, Loss Value = 0.11955393105745316
# Epoch # 248, Time Step # 191, Loss Value = 0.08402131497859955
# Epoch # 248, Time Step # 192, Loss Value = 0.09611985087394714
# Epoch # 248, Time Step # 193, Loss Value = 0.06928011029958725
# Epoch # 248, Time Step # 194, Loss Value = 0.10365208238363266
# Epoch # 248, Time Step # 195, Loss Value = 0.04439853876829147
# Epoch # 248, Time Step # 196, Loss Value = 0.01130588911473751
# Epoch # 248, Time Step # 197, Loss Value = 0.030634718015789986
# Epoch # 248, Time Step # 198, Loss Value = 0.08841452747583389
# Epoch # 248, Time Step # 199, Loss Value = 0.017306344583630562
# Epoch # 249, Time Step # 0, Loss Value = 0.08263105899095535
# Epoch # 249, Time Step # 1, Loss Value = 0.020083099603652954
# Epoch # 249, Time Step # 2, Loss Value = 0.06229517608880997
# Epoch # 249, Time Step # 3, Loss Value = 0.0275244303047657
# Epoch # 249, Time Step # 4, Loss Value = 0.03445946425199509
# Epoch # 249, Time Step # 5, Loss Value = 0.03744189441204071
# Epoch # 249, Time Step # 6, Loss Value = 0.029664544388651848
# Epoch # 249, Time Step # 7, Loss Value = 0.0257957074791193
# Epoch # 249, Time Step # 8, Loss Value = 0.035066381096839905
# Epoch # 249, Time Step # 9, Loss Value = 0.05211140960454941
# Epoch # 249, Time Step # 10, Loss Value = 0.04425596818327904
# Epoch # 249, Time Step # 11, Loss Value = 0.02540929615497589
# Epoch # 249, Time Step # 12, Loss Value = 0.035838063806295395
# Epoch # 249, Time Step # 13, Loss Value = 0.01427716389298439
# Epoch # 249, Time Step # 14, Loss Value = 0.0168764591217041
# Epoch # 249, Time Step # 15, Loss Value = 0.01785464398562908
# Epoch # 249, Time Step # 16, Loss Value = 0.02313571237027645
# Epoch # 249, Time Step # 17, Loss Value = 0.02259913645684719
# Epoch # 249, Time Step # 18, Loss Value = 0.020009977743029594
# Epoch # 249, Time Step # 19, Loss Value = 0.02136738784611225
# Epoch # 249, Time Step # 20, Loss Value = 0.03574594482779503
# Epoch # 249, Time Step # 21, Loss Value = 0.03144219517707825
# Epoch # 249, Time Step # 22, Loss Value = 0.0585801862180233
# Epoch # 249, Time Step # 23, Loss Value = 0.06814367324113846
# Epoch # 249, Time Step # 24, Loss Value = 0.02558274008333683
# Epoch # 249, Time Step # 25, Loss Value = 0.05282451957464218
# Epoch # 249, Time Step # 26, Loss Value = 0.02756938338279724
# Epoch # 249, Time Step # 27, Loss Value = 0.03052186407148838
# Epoch # 249, Time Step # 28, Loss Value = 0.016837401315569878
# Epoch # 249, Time Step # 29, Loss Value = 0.026830552145838737
# Epoch # 249, Time Step # 30, Loss Value = 0.023412207141518593
# Epoch # 249, Time Step # 31, Loss Value = 0.04109024628996849
# Epoch # 249, Time Step # 32, Loss Value = 0.02288406528532505
# Epoch # 249, Time Step # 33, Loss Value = 0.02146081253886223
# Epoch # 249, Time Step # 34, Loss Value = 0.030844368040561676
# Epoch # 249, Time Step # 35, Loss Value = 0.025484293699264526
# Epoch # 249, Time Step # 36, Loss Value = 0.025134285911917686
# Epoch # 249, Time Step # 37, Loss Value = 0.032609354704618454
# Epoch # 249, Time Step # 38, Loss Value = 0.05444454774260521
# Epoch # 249, Time Step # 39, Loss Value = 0.009802186861634254
# Epoch # 249, Time Step # 40, Loss Value = 0.02426980808377266
# Epoch # 249, Time Step # 41, Loss Value = 0.06062593683600426
# Epoch # 249, Time Step # 42, Loss Value = 0.028395559638738632
# Epoch # 249, Time Step # 43, Loss Value = 0.02441640943288803
# Epoch # 249, Time Step # 44, Loss Value = 0.034648746252059937
# Epoch # 249, Time Step # 45, Loss Value = 0.035767726600170135
# Epoch # 249, Time Step # 46, Loss Value = 0.012445718981325626
# Epoch # 249, Time Step # 47, Loss Value = 0.043687254190444946
# Epoch # 249, Time Step # 48, Loss Value = 0.022282076999545097
# Epoch # 249, Time Step # 49, Loss Value = 0.028547709807753563
# Epoch # 249, Time Step # 50, Loss Value = 0.026328742504119873
# Epoch # 249, Time Step # 51, Loss Value = 0.029020244255661964
# Epoch # 249, Time Step # 52, Loss Value = 0.021428564563393593
# Epoch # 249, Time Step # 53, Loss Value = 0.030593903735280037
# Epoch # 249, Time Step # 54, Loss Value = 0.03470069169998169
# Epoch # 249, Time Step # 55, Loss Value = 0.0711594820022583
# Epoch # 249, Time Step # 56, Loss Value = 0.028323708102107048
# Epoch # 249, Time Step # 57, Loss Value = 0.02834031730890274
# Epoch # 249, Time Step # 58, Loss Value = 0.021037299185991287
# Epoch # 249, Time Step # 59, Loss Value = 0.026022236794233322
# Epoch # 249, Time Step # 60, Loss Value = 0.08405857533216476
# Epoch # 249, Time Step # 61, Loss Value = 0.028526546433568
# Epoch # 249, Time Step # 62, Loss Value = 0.023896748200058937
# Epoch # 249, Time Step # 63, Loss Value = 0.0224436204880476
# Epoch # 249, Time Step # 64, Loss Value = 0.03593326732516289
# Epoch # 249, Time Step # 65, Loss Value = 0.0509117916226387
# Epoch # 249, Time Step # 66, Loss Value = 0.040324945002794266
# Epoch # 249, Time Step # 67, Loss Value = 0.02321004308760166
# Epoch # 249, Time Step # 68, Loss Value = 0.06246303394436836
# Epoch # 249, Time Step # 69, Loss Value = 0.042096417397260666
# Epoch # 249, Time Step # 70, Loss Value = 0.05667949095368385
# Epoch # 249, Time Step # 71, Loss Value = 0.06529196351766586
# Epoch # 249, Time Step # 72, Loss Value = 0.09016860276460648
# Epoch # 249, Time Step # 73, Loss Value = 0.05655583366751671
# Epoch # 249, Time Step # 74, Loss Value = 0.0521145723760128
# Epoch # 249, Time Step # 75, Loss Value = 0.06156575307250023
# Epoch # 249, Time Step # 76, Loss Value = 0.09174846857786179
# Epoch # 249, Time Step # 77, Loss Value = 0.06390781700611115
# Epoch # 249, Time Step # 78, Loss Value = 0.08677125722169876
# Epoch # 249, Time Step # 79, Loss Value = 0.04303230345249176
# Epoch # 249, Time Step # 80, Loss Value = 0.13627396523952484
# Epoch # 249, Time Step # 81, Loss Value = 0.07719078660011292
# Epoch # 249, Time Step # 82, Loss Value = 0.06015895679593086
# Epoch # 249, Time Step # 83, Loss Value = 0.08065637946128845
# Epoch # 249, Time Step # 84, Loss Value = 0.08777928352355957
# Epoch # 249, Time Step # 85, Loss Value = 0.09333880990743637
# Epoch # 249, Time Step # 86, Loss Value = 0.06448357552289963
# Epoch # 249, Time Step # 87, Loss Value = 0.0832306295633316
# Epoch # 249, Time Step # 88, Loss Value = 0.04681960120797157
# Epoch # 249, Time Step # 89, Loss Value = 0.07449889183044434
# Epoch # 249, Time Step # 90, Loss Value = 0.08061778545379639
# Epoch # 249, Time Step # 91, Loss Value = 0.1185959130525589
# Epoch # 249, Time Step # 92, Loss Value = 0.05417421832680702
# Epoch # 249, Time Step # 93, Loss Value = 0.07106421887874603
# Epoch # 249, Time Step # 94, Loss Value = 0.0350150465965271
# Epoch # 249, Time Step # 95, Loss Value = 0.00775514030829072
# Epoch # 249, Time Step # 96, Loss Value = 0.016905561089515686
# Epoch # 249, Time Step # 97, Loss Value = 0.04091249033808708
# Epoch # 249, Time Step # 98, Loss Value = 0.06599141657352448
# Epoch # 249, Time Step # 99, Loss Value = 0.04314805567264557
# Epoch # 249, Time Step # 100, Loss Value = 0.037918586283922195
# Epoch # 249, Time Step # 101, Loss Value = 0.06645118445158005
# Epoch # 249, Time Step # 102, Loss Value = 0.06045720353722572
# Epoch # 249, Time Step # 103, Loss Value = 0.09278322756290436
# Epoch # 249, Time Step # 104, Loss Value = 0.07981087267398834
# Epoch # 249, Time Step # 105, Loss Value = 0.071294404566288
# Epoch # 249, Time Step # 106, Loss Value = 0.115633025765419
# Epoch # 249, Time Step # 107, Loss Value = 0.06782188266515732
# Epoch # 249, Time Step # 108, Loss Value = 0.0332183912396431
# Epoch # 249, Time Step # 109, Loss Value = 0.019098632037639618
# Epoch # 249, Time Step # 110, Loss Value = 0.05176195502281189
# Epoch # 249, Time Step # 111, Loss Value = 0.019706569612026215
# Epoch # 249, Time Step # 112, Loss Value = 0.027478937059640884
# Epoch # 249, Time Step # 113, Loss Value = 0.0397430881857872
# Epoch # 249, Time Step # 114, Loss Value = 0.0788230374455452
# Epoch # 249, Time Step # 115, Loss Value = 0.05516374111175537
# Epoch # 249, Time Step # 116, Loss Value = 0.08966609090566635
# Epoch # 249, Time Step # 117, Loss Value = 0.05955996736884117
# Epoch # 249, Time Step # 118, Loss Value = 0.0758332833647728
# Epoch # 249, Time Step # 119, Loss Value = 0.03535505011677742
# Epoch # 249, Time Step # 120, Loss Value = 0.060685284435749054
# Epoch # 249, Time Step # 121, Loss Value = 0.08235426992177963
# Epoch # 249, Time Step # 122, Loss Value = 0.10147634148597717
# Epoch # 249, Time Step # 123, Loss Value = 0.05928279459476471
# Epoch # 249, Time Step # 124, Loss Value = 0.08191061019897461
# Epoch # 249, Time Step # 125, Loss Value = 0.04290331155061722
# Epoch # 249, Time Step # 126, Loss Value = 0.057179976254701614
# Epoch # 249, Time Step # 127, Loss Value = 0.09205925464630127
# Epoch # 249, Time Step # 128, Loss Value = 0.03528190404176712
# Epoch # 249, Time Step # 129, Loss Value = 0.017748350277543068
# Epoch # 249, Time Step # 130, Loss Value = 0.022558707743883133
# Epoch # 249, Time Step # 131, Loss Value = 0.0520637072622776
# Epoch # 249, Time Step # 132, Loss Value = 0.08584300428628922
# Epoch # 249, Time Step # 133, Loss Value = 0.12245111912488937
# Epoch # 249, Time Step # 134, Loss Value = 0.09205318242311478
# Epoch # 249, Time Step # 135, Loss Value = 0.10785090923309326
# Epoch # 249, Time Step # 136, Loss Value = 0.11900731921195984
# Epoch # 249, Time Step # 137, Loss Value = 0.16071629524230957
# Epoch # 249, Time Step # 138, Loss Value = 0.1294514685869217
# Epoch # 249, Time Step # 139, Loss Value = 0.08229959011077881
# Epoch # 249, Time Step # 140, Loss Value = 0.09569831937551498
# Epoch # 249, Time Step # 141, Loss Value = 0.07355881482362747
# Epoch # 249, Time Step # 142, Loss Value = 0.08066252619028091
# Epoch # 249, Time Step # 143, Loss Value = 0.09809388220310211
# Epoch # 249, Time Step # 144, Loss Value = 0.15413206815719604
# Epoch # 249, Time Step # 145, Loss Value = 0.08067193627357483
# Epoch # 249, Time Step # 146, Loss Value = 0.24098801612854004
# Epoch # 249, Time Step # 147, Loss Value = 0.2043367177248001
# Epoch # 249, Time Step # 148, Loss Value = 0.09110433608293533
# Epoch # 249, Time Step # 149, Loss Value = 0.05207956209778786
# Epoch # 249, Time Step # 150, Loss Value = 0.09086054563522339
# Epoch # 249, Time Step # 151, Loss Value = 0.09464141726493835
# Epoch # 249, Time Step # 152, Loss Value = 0.09993743151426315
# Epoch # 249, Time Step # 153, Loss Value = 0.15624681115150452
# Epoch # 249, Time Step # 154, Loss Value = 0.0996883288025856
# Epoch # 249, Time Step # 155, Loss Value = 0.04157467186450958
# Epoch # 249, Time Step # 156, Loss Value = 0.14277561008930206
# Epoch # 249, Time Step # 157, Loss Value = 0.10199755430221558
# Epoch # 249, Time Step # 158, Loss Value = 0.06367246061563492
# Epoch # 249, Time Step # 159, Loss Value = 0.02197517827153206
# Epoch # 249, Time Step # 160, Loss Value = 0.04713791236281395
# Epoch # 249, Time Step # 161, Loss Value = 0.09725981950759888
# Epoch # 249, Time Step # 162, Loss Value = 0.07521088421344757
# Epoch # 249, Time Step # 163, Loss Value = 0.13083256781101227
# Epoch # 249, Time Step # 164, Loss Value = 0.2495729625225067
# Epoch # 249, Time Step # 165, Loss Value = 0.04921803995966911
# Epoch # 249, Time Step # 166, Loss Value = 0.06863822042942047
# Epoch # 249, Time Step # 167, Loss Value = 0.09081865102052689
# Epoch # 249, Time Step # 168, Loss Value = 0.012637526728212833
# Epoch # 249, Time Step # 169, Loss Value = 0.05867008864879608
# Epoch # 249, Time Step # 170, Loss Value = 0.054861538112163544
# Epoch # 249, Time Step # 171, Loss Value = 0.06361229717731476
# Epoch # 249, Time Step # 172, Loss Value = 0.011425266973674297
# Epoch # 249, Time Step # 173, Loss Value = 0.022966086864471436
# Epoch # 249, Time Step # 174, Loss Value = 0.027194363996386528
# Epoch # 249, Time Step # 175, Loss Value = 0.06528936326503754
# Epoch # 249, Time Step # 176, Loss Value = 0.06139013543725014
# Epoch # 249, Time Step # 177, Loss Value = 0.06751922518014908
# Epoch # 249, Time Step # 178, Loss Value = 0.07950473576784134
# Epoch # 249, Time Step # 179, Loss Value = 0.04805946350097656
# Epoch # 249, Time Step # 180, Loss Value = 0.046079616993665695
# Epoch # 249, Time Step # 181, Loss Value = 0.09106793254613876
# Epoch # 249, Time Step # 182, Loss Value = 0.10421236604452133
# Epoch # 249, Time Step # 183, Loss Value = 0.07905248552560806
# Epoch # 249, Time Step # 184, Loss Value = 0.07916413992643356
# Epoch # 249, Time Step # 185, Loss Value = 0.09493560343980789
# Epoch # 249, Time Step # 186, Loss Value = 0.09481338411569595
# Epoch # 249, Time Step # 187, Loss Value = 0.03457603231072426
# Epoch # 249, Time Step # 188, Loss Value = 0.08730829507112503
# Epoch # 249, Time Step # 189, Loss Value = 0.06321842223405838
# Epoch # 249, Time Step # 190, Loss Value = 0.11789131909608841
# Epoch # 249, Time Step # 191, Loss Value = 0.08330190181732178
# Epoch # 249, Time Step # 192, Loss Value = 0.10668179392814636
# Epoch # 249, Time Step # 193, Loss Value = 0.06553571671247482
# Epoch # 249, Time Step # 194, Loss Value = 0.11029694229364395
# Epoch # 249, Time Step # 195, Loss Value = 0.047233257442712784
# Epoch # 249, Time Step # 196, Loss Value = 0.00896742194890976
# Epoch # 249, Time Step # 197, Loss Value = 0.028682461008429527
# Epoch # 249, Time Step # 198, Loss Value = 0.07721462100744247
# Epoch # 249, Time Step # 199, Loss Value = 0.015244178473949432

# %%
torch.save(network.state_dict(),"model.pth")
print("model path downloaded")
# Out:
# model path downloaded

# %%
def generate_translation(eng_sentence):

    tokenized_eng_sentence = src_sent_tokenizer.tokenize(eng_sentence)
    token_ids = src_sent_tokenizer.convert_tokens_to_ids(tokenized_eng_sentence)
    token_ids_tensor = torch.tensor(token_ids)
    token_ids_tensor = torch.unsqueeze(token_ids_tensor,0)

    if torch.cuda.is_available():
        device = torch.device("cuda")
        token_ids_tensor = token_ids_tensor.to(device)

    encoder_outputs,(final_encoder_output,final_candidate_cell_state) = network.encoder(token_ids_tensor)
    decoder_first_time_step_input = torch.tensor([[1]])

    if torch.cuda.is_available():
        encoder_outputs = encoder_outputs.to(device)
        final_encoder_output = final_encoder_output.to(device)
        final_candidate_cell_state = final_candidate_cell_state.to(device)
        decoder_first_time_step_input = decoder_first_time_step_input.to(device)

    decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(decoder_first_time_step_input,
                                                                          final_encoder_output,
                                                                          final_candidate_cell_state)

    generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
    generated_token_id = torch.unsqueeze(generated_token_id,1)

    hindi_translated_sentence = str()
    hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    if torch.cuda.is_available():
        generated_token_id = generated_token_id.to(device)
        hidden_decoder_output = hidden_decoder_output.to(device)
        hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)
        
    for i in range(Nd-1):
        
        decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(generated_token_id,
                                                                                                hidden_decoder_output,
                                                                                                hidden_decoder_cell_state)
        generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
        generated_token_id = torch.unsqueeze(generated_token_id,1)

        if torch.cuda.is_available():
            generated_token_id = generated_token_id.to(device)
            hidden_decoder_output = hidden_decoder_output.to(device)
            hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)

        if generated_token_id.item() == Vd["<EOS>"]:
            break

        hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    return hindi_translated_sentence
